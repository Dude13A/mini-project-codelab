# %%
import pandas as pd 
import numpy as np
df=pd.read_csv(r"C:\Users\nithu\Downloads\loan.csv")
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
#first five rows of data 
df.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
#return the bottom five rows of the dataframe
df.tail(5)
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 362       0        0         3+          1              1             4009
# 363       0        0          0          0              0             4158
# 364       0        1          0          0              0             3250
# 365       0        0          0          0              0             5000
# 366       0        1          0          0              1             9200
#
#      CoapplicantIncome LoanAmount Loan_Amount_Term Credit_History  \
# 362               1777      113.0            360.0            1.0
# 363                709      115.0            360.0            1.0
# 364               1993      126.0            360.0            0.0
# 365               2393      158.0            360.0            1.0
# 366                  0       98.0            180.0            1.0
#
#     Property_Area
# 362         Urban
# 363         Urban
# 364     Semiurban
# 365         Rural
# 366         Rural

# %%
#Randomly select the data
df.sample(10)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 109  LP001573   Male     Yes          0  Not Graduate            No
# 68   LP001359   Male     Yes          0      Graduate            No
# 196  LP002090   Male     Yes          1      Graduate            No
# 154  LP001855   Male     Yes          2      Graduate            No
# 352  LP002907   Male     Yes          0      Graduate            No
# 241  LP002339   Male     Yes          0      Graduate            No
# 99   LP001527   Male     Yes         3+      Graduate            No
# 127  LP001663   Male     Yes          2      Graduate            No
# 60   LP001332   Male     Yes          0  Not Graduate            No
# 107  LP001567   Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 109             4523               1350       165.0             360.0
# 68              7666                  0       187.0             360.0
# ...

# %%
#Gives statstical summary of data
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
#Information about your df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
#Returns the column
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
#Data types of the columns
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome      int64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# dtype: object

# %%
#Shape of the df
df.shape
# Out:
# (367, 12)

# %%
df['Married']
# Out:
# 0      Yes
# 1      Yes
# 2      Yes
# 3      Yes
# 4       No
#       ...
# 362    Yes
# 363    Yes
# 364     No
# 365    Yes
# 366     No
# Name: Married, Length: 367, dtype: object

# %%
df[['Gender','Loan_ID','Education']]
# Out:
#     Gender   Loan_ID     Education
# 0     Male  LP001015      Graduate
# 1     Male  LP001022      Graduate
# 2     Male  LP001031      Graduate
# 3     Male  LP001035      Graduate
# 4     Male  LP001051  Not Graduate
# ..     ...       ...           ...
# 362   Male  LP002971  Not Graduate
# 363   Male  LP002975      Graduate
# 364   Male  LP002980      Graduate
# 365   Male  LP002986      Graduate
# 366   Male  LP002989      Graduate
#
# [367 rows x 3 columns]

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      286
# Female     70
# Name: count, dtype: int64

# %%
df['LoanAmount'].value_counts()
# Out:
# LoanAmount
# 150.0    12
# 125.0    11
# 110.0    10
# 100.0     9
# 90.0      9
#          ..
# 71.0      1
# 157.0     1
# 93.0      1
# 61.0      1
# 98.0      1
# Name: count, Length: 144, dtype: int64

# %%
df[df['LoanAmount']>100]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 5    LP001054   Male     Yes          0  Not Graduate           Yes
# 7    LP001056   Male     Yes          2  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 359  LP002962   Male      No          0      Graduate            No
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
#display the rows from the dataframe gender =male
df[df['Gender']=='Female']
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 6    LP001055  Female      No          1  Not Graduate            No
# 14   LP001096  Female      No          0      Graduate            No
# 21   LP001124  Female      No         3+  Not Graduate            No
# 23   LP001135  Female      No          0  Not Graduate            No
# 30   LP001177  Female      No          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 332  LP002826  Female     Yes          1  Not Graduate            No
# 333  LP002843  Female     Yes          0      Graduate            No
# 336  LP002853  Female      No          0  Not Graduate            No
# 339  LP002858  Female      No          0      Graduate            No
# 360  LP002965  Female     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df[df['Credit_History']==1]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# 5    LP001054   Male     Yes          0  Not Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 361  LP002969   Male     Yes          1      Graduate            No
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
#display the rows donot have hypertension
df[df['Credit_History']==0]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 7    LP001056    Male     Yes          2  Not Graduate            No
# 13   LP001094    Male     Yes          2      Graduate           NaN
# 25   LP001153    Male      No          0      Graduate            No
# 35   LP001203    Male      No          0      Graduate            No
# 55   LP001313    Male      No          0      Graduate            No
# 58   LP001323  Female     Yes          2      Graduate            No
# 63   LP001347  Female      No          0      Graduate            No
# 66   LP001352    Male     Yes          0  Not Graduate            No
# 67   LP001358    Male     Yes          0      Graduate            No
# 69   LP001361    Male     Yes          0      Graduate            No
# 80   LP001420    Male     Yes         3+      Graduate            No
# 82   LP001445    Male     Yes          2  Not Graduate            No
# 84   LP001450    Male     Yes          0      Graduate            No
# ...

# %%
df[(df['Credit_History']==1)&(df['LoanAmount']>100)]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 5    LP001054   Male     Yes          0  Not Graduate           Yes
# 8    LP001059   Male     Yes          2      Graduate           NaN
# ..        ...    ...     ...        ...           ...           ...
# 355  LP002932   Male     Yes         3+      Graduate            No
# 359  LP002962   Male      No          0      Graduate            No
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df[(df['Dependents']==1)|(df['Education']=='Graduate')]
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001015   Male     Yes          0  Graduate            No
# 1    LP001022   Male     Yes          1  Graduate            No
# 2    LP001031   Male     Yes          2  Graduate            No
# 3    LP001035   Male     Yes          2  Graduate            No
# 8    LP001059   Male     Yes          2  Graduate           NaN
# ..        ...    ...     ...        ...       ...           ...
# 361  LP002969   Male     Yes          1  Graduate            No
# 363  LP002975   Male     Yes          0  Graduate            No
# 364  LP002980   Male      No          0  Graduate            No
# 365  LP002986   Male     Yes          0  Graduate            No
# 366  LP002989   Male      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
s=df['Education'].value_counts()
type(s)
print(s)
x=s.index
y=s.values
import matplotlib.pyplot as plt
plt.bar(x,y)
plt.show()
# Out:
# Education
# Graduate        283
# Not Graduate     84
# Name: count, dtype: int64

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
# #filling the null values with median of LoanAmount
# med=df['LoanAmount'].median()
# df.fillna(med)
# df.fillna(df['LoanAmount'].median())

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      286
# Female     70
# Name: count, dtype: int64

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# 0     200
# 2      59
# 1      58
# 3+     40
# Name: count, dtype: int64

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# 0     200
# 2      59
# 1      58
# 3+     40
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      286
# Female     70
# Name: count, dtype: int64

# %%
df['Married'].value_counts()
# Out:
# Married
# Yes    233
# No     134
# Name: count, dtype: int64

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# 0     200
# 2      59
# 1      58
# 3+     40
# Name: count, dtype: int64

# %%
df['Education'].value_counts()
# Out:
# Education
# Graduate        283
# Not Graduate     84
# Name: count, dtype: int64

# %%
df['Self_Employed'].value_counts()
# Out:
# Self_Employed
# No     307
# Yes     37
# Name: count, dtype: int64

# %%
df['LoanAmount'].unique()
df['LoanAmount'].value_counts()
# Out:
# LoanAmount
# 150.0    12
# 125.0    11
# 110.0    10
# 100.0     9
# 90.0      9
#          ..
# 71.0      1
# 157.0     1
# 93.0      1
# 61.0      1
# 98.0      1
# Name: count, Length: 144, dtype: int64

# %%
df['Loan_Amount_Term'].value_counts()
# Out:
# Loan_Amount_Term
# 360.0    311
# 180.0     22
# 480.0      8
# 300.0      7
# 240.0      4
# 84.0       3
# 60.0       1
# 12.0       1
# 350.0      1
# 36.0       1
# 120.0      1
# 6.0        1
# Name: count, dtype: int64

# %%
df['Credit_History'].value_counts()
# Out:
# Credit_History
# 1.0    279
# 0.0     59
# Name: count, dtype: int64

# %%
df['Property_Area'].value_counts()
# Out:
# Property_Area
# Urban        140
# Semiurban    116
# Rural        111
# Name: count, dtype: int64

# %%
df['Gender'].fillna('Female',inplace=True)
print(df)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df['Dependents'].fillna('1',inplace=True)
print(df)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df['Self_Employed'].fillna('Yes',inplace=True)
print(df)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
df['LoanAmount'].fillna('71.0',inplace=True)
print(df)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome LoanAmount  Loan_Amount_Term  \
# 0               5720                  0      110.0             360.0
# ...

# %%
df['Loan_Amount_Term'].fillna('120.0',inplace=True)
print(df)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 0               5720                  0      110.0            360.0
# ...

# %%
df['Credit_History'].fillna('0.0',inplace=True)
print(df)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 0               5720                  0      110.0            360.0
# ...

# %%
df.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             367 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         367 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      367 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         367 non-null    object
#  9   Loan_Amount_Term   367 non-null    object
#  10  Credit_History     367 non-null    object
#  11  Property_Area      367 non-null    object
# dtypes: int64(2), object(10)
# memory usage: 34.5+ KB

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
df.drop('Loan_ID',axis=1,inplace=True)
print(df)
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0     Male     Yes          0      Graduate            No             5720
# 1     Male     Yes          1      Graduate            No             3076
# 2     Male     Yes          2      Graduate            No             5000
# 3     Male     Yes          2      Graduate            No             2340
# 4     Male      No          0  Not Graduate            No             3276
# ..     ...     ...        ...           ...           ...              ...
# 362   Male     Yes         3+  Not Graduate           Yes             4009
# 363   Male     Yes          0      Graduate            No             4158
# 364   Male      No          0      Graduate            No             3250
# 365   Male     Yes          0      Graduate            No             5000
# 366   Male      No          0      Graduate           Yes             9200
#
#      CoapplicantIncome LoanAmount Loan_Amount_Term Credit_History  \
# ...

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
# Male=0
# Female=1

# %%
# Map method
df["Gender"]=df["Gender"].map({"Male":0,"Female":1})
df["Gender"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 362    0
# 363    0
# 364    0
# 365    0
# 366    0
# Name: Gender, Length: 367, dtype: int64

# %%
df['Married'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
# Yes=0
# No=1

# %%
# Map method
df["Married"]=df["Married"].map({"Yes":0,"No":1})
df["Married"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 362    0
# 363    0
# 364    1
# 365    0
# 366    1
# Name: Married, Length: 367, dtype: int64

# %%
df['Education'].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
# Graduste=0
# Not Graduate=1

# %%
# Map method
df["Education"]=df["Education"].map({"Graduate":0,"Not Graduate":1})
df["Education"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 362    1
# 363    0
# 364    0
# 365    0
# 366    0
# Name: Education, Length: 367, dtype: int64

# %%
df['Self_Employed'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
#No =1
#Yes=0

# %%
# Map method
df["Self_Employed"]=df["Self_Employed"].map({"No":0,"Yes":1})
df["Self_Employed"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 362    1
# 363    0
# 364    0
# 365    0
# 366    1
# Name: Self_Employed, Length: 367, dtype: int64
